# %% [markdown]
# ## Детекция ударов кулаками/другим холодным оружием
#
# Видео: https://www.youtube.com/watch?v=ERDmPJ_0QJc&t=

# %%
import numpy as np
import cv2 # conda install -c conda-forge opencv (in Anaconda prompt)
import matplotlib.pyplot as plt
# %matplotlib inline

def see_plot(pict):
    plt.figure(figsize=(12,9))
    plt.imshow(pict)
    plt.grid()
    plt.show()

# %%
def r_hands(one_kadr):
    ...
    return ...

# %%
# %%time

cap = cv2.VideoCapture("videoplayback.mp4")
picts = []
h = []
i = 0

while True:
    n_i = []
    ret,frame=cap.read()
    if not ret:
        break
    i += 1
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) # 718x1280
    h.append(r_hands(gray_img)) # оптимизация: использовать только тогда, когда активно оружие №3 (холодное/кулаки)
    #-----------------------------
    picts.append(gray_img)
    
h = np.array(h)
len(picts)
# Out:
# CPU times: user 1min 56s, sys: 593 ms, total: 1min 57s
# Wall time: 14.2 s
# 9212

# %%
# детектим максимальный замах.
for i in range(50):
    if 42>h[i]>38:
        print(i)
# Out:
# 9
# 20
# 28
# 37

# %%
# кадр без удара
see_plot(picts[3])

# %%
# пример ударов (для разбития ящика нужно 4 удара, все задатектили)
see_plot(picts[9])
see_plot(picts[20])
see_plot(picts[28])
see_plot(picts[37])
