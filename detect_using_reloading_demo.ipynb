# %% [markdown]
# Видео: https://www.youtube.com/watch?v=ERDmPJ_0QJc&t=

# %%
import numpy as np
import cv2 # conda install -c conda-forge opencv (in Anaconda prompt)
import matplotlib.pyplot as plt
# %matplotlib inline

def see_plot(pict):
    plt.figure(figsize=(12,9))
    plt.imshow(pict)
    plt.grid()
    plt.show()

# %%
def detect_using_reload(...):
    ...
    return ...

def postproc_numbers7((...):
    ...
    return ...

# %%
# %%time

cap = cv2.VideoCapture("videoplayback.mp4")
picts = []
actions = []
i = 0

while True:
    n_i = []
    ret,frame=cap.read()
    if not ret: # or i==28*130
        break
    i += 1
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) # 718x1280
    actions.append(detect_using_reload(gray_img))
    #-----------------------------
    picts.append(gray_img)

actions = np.array(actions)   
n1 = actions.copy()
n1 = postproc_numbers7(n1)
len(picts),len(actions)
# Out:
# CPU times: user 1min 56s, sys: 799 ms, total: 1min 57s
# Wall time: 14.6 s
# (9212, 9212)

# %%
#n1 = actions.copy()
#n1 = postproc_numbers7(n1)
plt.figure(figsize=(20,5))
#plt.plot(actions, color='green', label='actions')
plt.plot(n1, color='blue', label='actions')
plt.ylim(0,6)
plt.xticks(range(0,len(picts)//100*100,100), rotation=70)
#plt.xlim(3570,3600)
plt.grid()
plt.legend();

# %%
see_plot(picts[3500])
see_plot(picts[6250])
