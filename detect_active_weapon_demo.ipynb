# %% [markdown]
# ## Определение текущего оружия в руках (1,2,3 или 4)
#
# Видео: https://www.youtube.com/watch?v=ERDmPJ_0QJc&t=

# %%
import numpy as np
import cv2 # conda install -c conda-forge opencv (in Anaconda prompt)
import matplotlib.pyplot as plt
# %matplotlib inline

def see_plot(pict):
    plt.figure(figsize=(12,9))
    plt.imshow(pict)
    plt.grid()
    plt.show()

# %%
def active_weapon(kadr):
    ...
    return ...

# %%
# %%time

cap = cv2.VideoCapture("videoplayback.mp4")
act_weap = []
picts = []
i = 0

while True:
    n_i = []
    ret,frame=cap.read()
    if not ret:
        break
    i += 1
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) # 718x1280
    act_weap.append(active_weapon(gray_img))
    #-----------------------------
    picts.append(gray_img)

act_weap = np.array(act_weap)
len(picts)
# Out:
# CPU times: user 1min 55s, sys: 649 ms, total: 1min 56s
# Wall time: 13.3 s
# 9212

# %%
plt.figure(figsize=(20,5))
plt.plot(act_weap, color='blue', label='active_weapon')
plt.ylim(0,6)
plt.xticks(range(0,len(picts)//100*100,5), rotation=70)
plt.xlim(0,300)
#plt.xlim(5000,5300)
plt.grid()
plt.legend();

# %%
see_plot(picts[169]) # 1
see_plot(picts[170]) # 3
see_plot(picts[174]) # 3
see_plot(picts[175]) # 1

# %%
see_plot(picts[190]) #3
see_plot(picts[191]) #1
