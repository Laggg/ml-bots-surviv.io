# %% [markdown]
# Видео: https://www.youtube.com/watch?v=ERDmPJ_0QJc&t=

# %%
import numpy as np
import cv2 # conda install -c conda-forge opencv (in Anaconda prompt)
import matplotlib.pyplot as plt
# %matplotlib inline

def see_plot(pict):
    plt.figure(figsize=(12,9))
    plt.imshow(pict)
    plt.grid()
    plt.show()

# %%
def open_close_door(...): #анализ каждого кадра
    ...
    return ...


def detect_action_with_door(...): #анализ последовательностей кадров
    ...
    return ...

# %%
# %%time

cap = cv2.VideoCapture("videoplayback.mp4")
picts = []
door = []
i = 0

while True:
    n_i = []
    ret,frame=cap.read()
    if not ret: # or i==28*130
        break
    i += 1
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) # 718x1280
    door.append(open_close_door(gray_img))
    #-----------------------------
    picts.append(gray_img)

door = np.array(door)
act_door = detect_action_with_door(door)
act_door
# Out:
# CPU times: user 1min 55s, sys: 2.31 s, total: 1min 57s
# Wall time: 16.7 s
# [(4836, 4837),
#  (4848, 4849),
#  (5626, 5627),
#  (8383, 8384),
#  (8396, 8397),
#  (8431, 8432),
#  (8455, 8456),
#  (8544, 8545),
#  (8606, 8607),
#  (8621, 8622),
#  (8629, 8630),
#  (8729, 8730),
#  (8772, 8773),
#  (8789, 8790)]

# %%
see_plot(picts[4836])
see_plot(picts[4837])

# %%
see_plot(picts[8789])
see_plot(picts[8790])
